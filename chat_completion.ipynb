# %% [markdown]
# <a href="https://colab.research.google.com/github/rkaruturi/Engineering-outskill/blob/master/chat_completion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, json, time, tempfile, pathlib
from openai import OpenAI
from google.colab import userdata

# Replace 'YOUR_SECRET_NAME' with the name you used in the Secrets manager (e.g., 'GEMINI_API_KEY')
api_key = userdata.get('OPENROUTER_API_KEY')
os.environ['OPENROUTER_API_KEY'] = api_key


client = OpenAI(
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1",
)

# %%
response = client.responses.create(
    model="gpt-5.2",
    input="What is the capital of France?"
)

print(response.output_text)

# %%
print(response)
print(response.usage)
